# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msn
import seaborn as sns

# %%
df = pd.read_csv("weather_dataset.csv")
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
###DataSet columns doesn,t have any nulls
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
#Showing Unique Values in Weather  Column
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
#Showing number of unique values of each column
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
#Showing all values in data frame
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
#Showing how many times of values appears in Weather Column
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#Matrix That identify how many nulls in each column
msn.matrix(df)
# Out:
# <Axes: >

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Showing number of unique values in Wind Speed_km/h Column
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
#Showing rows that wheather is Clear in it
df[df.Weather=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#Show Rows that wind speed is 4 in it
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
#Rename Weather Column to Weather Condition
df.rename(columns={"Weather":"Weather_condition"},inplace = True)

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#Showing average values in Visibilty Columns
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
#Calculatind standard deviation in pressure columns
df['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %%
#Calculating varience in humidity column
df['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
#Showing all values that are Snow in Weather condition column

# %%
#Showing values that above 25 in wind speed and 25 in Visibilty column
df[(df['Wind Speed_km/h']>24 & (df['Visibility_km']==25))]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather_condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
###Show mean values of columns related to Weather_condition column (Categorical column )
df.groupby("Weather_condition").mean()
# Out:
#                                                             Date/Time  \
# Weather_condition
# Clear                                   2012-06-25 18:03:12.760180992
# Cloudy                                  2012-07-01 16:51:29.583333376
# Drizzle                                 2012-09-17 15:00:00.000000000
# Drizzle,Fog                             2012-06-30 00:44:15.000000000
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00.000000000
# Drizzle,Snow                            2012-12-18 16:30:00.000000000
# Drizzle,Snow,Fog                        2012-12-19 20:56:00.000000000
# Fog                                     2012-06-24 21:08:00.000000000
# Freezing Drizzle                        2012-03-05 23:25:42.857142784
# Freezing Drizzle,Fog                    2012-04-30 06:20:00.000000000
# Freezing Drizzle,Haze                   2012-02-01 12:00:00.000000000
# Freezing Drizzle,Snow                   2012-06-27 12:32:43.636363520
# ...

# %%
#Maximim and minimum values of each columns for  Weather_Condition
df.groupby("Weather_condition").max()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather_condition
# Clear                                   2012-12-30 20:00:00    32.8
# Cloudy                                  2012-12-31 06:00:00    30.5
# Drizzle                                 2012-12-22 01:00:00    18.8
# Drizzle,Fog                             2012-12-19 10:00:00    19.9
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-19 18:00:00     1.2
# Drizzle,Snow,Fog                        2012-12-22 03:00:00     1.1
# Fog                                     2012-12-29 10:00:00    20.8
# Freezing Drizzle                        2012-12-17 00:00:00    -2.3
# Freezing Drizzle,Fog                    2012-12-10 05:00:00    -0.3
# Freezing Drizzle,Haze                   2012-02-01 13:00:00    -5.0
# Freezing Drizzle,Snow                   2012-12-28 02:00:00    -3.3
# ...

# %%
df.groupby("Weather_condition").min()
# Out:
#                                                   Date/Time  Temp_C  \
# Weather_condition
# Clear                                   2012-01-03 19:00:00   -23.3
# Cloudy                                  2012-01-01 17:00:00   -21.4
# Drizzle                                 2012-01-23 21:00:00     1.1
# Drizzle,Fog                             2012-01-23 20:00:00     0.0
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00     0.4
# Drizzle,Snow                            2012-12-17 15:00:00     0.9
# Drizzle,Snow,Fog                        2012-12-18 21:00:00     0.3
# Fog                                     2012-01-01 00:00:00   -16.0
# Freezing Drizzle                        2012-01-07 11:00:00    -9.0
# Freezing Drizzle,Fog                    2012-01-01 02:00:00    -6.4
# Freezing Drizzle,Haze                   2012-02-01 11:00:00    -5.8
# Freezing Drizzle,Snow                   2012-01-13 03:00:00    -8.3
# ...

# %%
#Showing all records for weather is Fog
df.loc[df['Weather_condition'] == 'Fog']
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather_condition
# 0                   4            8.0     101.24               Fog
# 1                   4            8.0     101.24               Fog
# ...

# %%
#Find all values if Weather is Cleat OR visibilty above 40
df[(df['Weather_condition']=='Clear')|(df['Visibility_km'])]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa     Weather_condition
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %%
###Correlation between features
df.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# Correlation between variable
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
corr = numerical_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Weather Dataset')
plt.show()

# %%
df.describe()
# Out:
#                  Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count                 8784  8784.000000       8784.000000  8784.000000
# mean   2012-07-01 23:30:00     8.798144          2.555294    67.431694
# min    2012-01-01 00:00:00   -23.300000        -28.500000    18.000000
# 25%    2012-04-01 11:45:00     0.100000         -5.900000    56.000000
# 50%    2012-07-01 23:30:00     9.300000          3.300000    68.000000
# 75%    2012-10-01 11:15:00    18.800000         11.800000    81.000000
# max    2012-12-31 23:00:00    33.000000         24.400000   100.000000
# std                    NaN    11.687883         10.883072    16.918881
#
#        Wind Speed_km/h  Visibility_km    Press_kPa
# count      8784.000000    8784.000000  8784.000000
# mean         14.945469      27.664447   101.051623
# min           0.000000       0.200000    97.520000
# 25%           9.000000      24.100000   100.560000
# 50%          13.000000      25.000000   101.070000
# ...

# %%
###Checking Outlier in Temp_C Column
Q1 = df['Visibility_km'].quantile(0.25)
Q3 = df['Visibility_km'].quantile(0.75)
IQR=Q3-Q1
######
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5 * IQR

# %%
df[(df['Visibility_km']<lower_bound)&(df['Visibility_km']>upper_bound)]
#There is no outlier found in this Column
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather_condition]
# Index: []
